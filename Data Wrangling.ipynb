# %%
import pandas as pd

# %% [markdown]
# # Data Wrangling
# The data for this project comes from Kaggle, with all data coming from 3 csv files.
#
# 1. nfl_teams
#     - Contains team data past and present
# 2. nfl_stadiums
#     - Contains stadium data past and present
# 3. spreadspoke_scores
#     - Contains score and weather data for all NFL games

# %%
## Importing csv files into panda DataFrames

# %%
filenameTeam = '/Users/Rezalution/Desktop/nfl-scores-and-betting-data/nfl_teams.csv'
filenameStadiums = '/Users/Rezalution/Desktop/nfl-scores-and-betting-data/nfl_stadiums.csv'
filenameGames = '/Users/Rezalution/Desktop/nfl-scores-and-betting-data/spreadspoke_scores.csv'

# %%
nflTeams = pd.read_csv(filenameTeam,encoding ='latin1')
nflStadiums = pd.read_csv(filenameStadiums,encoding ='latin1')
nflGames = pd.read_csv(filenameScores,encoding ='latin1')

# %%
## Top view of the 3 DataFrames

# %%
nflTeams.head()
# Out:
#              team_name team_name_short team_id team_id_pfr team_conference  \
# 0    Arizona Cardinals       Cardinals     ARI         CRD             NFC
# 1    Phoenix Cardinals       Cardinals     ARI         CRD             NFC
# 2  St. Louis Cardinals       Cardinals     ARI         ARI             NFC
# 3      Atlanta Falcons         Falcons     ATL         ATL             NFC
# 4     Baltimore Ravens          Ravens     BAL         RAV             AFC
#
#   team_division team_conference_pre2002 team_division_pre2002
# 0      NFC West                     NFC              NFC West
# 1           NaN                     NFC              NFC East
# 2           NaN                     NFC              NFC East
# 3     NFC South                     NFC              NFC West
# 4     AFC North                     AFC           AFC Central

# %%
nflStadiums.head()
# Out:
#         stadium_name   stadium_location  stadium_open  stadium_close  \
# 0         Alamo Dome    San Antonio, TX           NaN            NaN
# 1     Alltel Stadium   Jacksonville, FL           NaN            NaN
# 2     Alumni Stadium  Chestnut Hill, MA           NaN            NaN
# 3    Anaheim Stadium        Anaheim, CA        1980.0         1994.0
# 4  Arrowhead Stadium    Kansas City, MO        1972.0            NaN
#
#   stadium_type                           stadium_address  \
# 0       indoor     100 Montana St, San Antonio, TX 78203
# 1          NaN                                       NaN
# 2      outdoor     Perimeter Rd, Chestnut Hill, MA 02467
# 3      outdoor  2000 E Gene Autry Way, Anaheim, CA 92806
# 4      outdoor     1 Arrowhead Dr, Kansas City, MO 64129
#
#   stadium_weather_station_code stadium_weather_type stadium_capacity  \
# 0                        78203                 dome            72000
# ...

# %%
nflGames.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/02/1966             1966             1             False
# 1    09/03/1966             1966             1             False
# 2    09/04/1966             1966             1             False
# 3    09/09/1966             1966             2             False
# 4    09/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Loading

# %%
## DataFrame info

# %% [markdown]
# ### NFL Teams

# %%
nflTeams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 8 columns):
# team_name                  41 non-null object
# team_name_short            41 non-null object
# team_id                    41 non-null object
# team_id_pfr                41 non-null object
# team_conference            41 non-null object
# team_division              33 non-null object
# team_conference_pre2002    41 non-null object
# team_division_pre2002      39 non-null object
# dtypes: object(8)
# memory usage: 2.7+ KB

# %% [markdown]
# The NFL Team dataframe contains 8 columns with 41 rows. There are 2 columns that contain NULL values (team_division and team_division_pre2002). The NULL values will not need to be editted nor the rows dropped because divisional data will not be used in the data analysis.

# %% [markdown]
# ### NFL Stadiums

# %%
nflStadiums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
# stadium_name                    100 non-null object
# stadium_location                100 non-null object
# stadium_open                    76 non-null float64
# stadium_close                   41 non-null float64
# stadium_type                    93 non-null object
# stadium_address                 91 non-null object
# stadium_weather_station_code    90 non-null object
# stadium_weather_type            93 non-null object
# stadium_capacity                39 non-null object
# stadium_surface                 53 non-null object
# STATION                         52 non-null object
# NAME                            52 non-null object
# LATITUDE                        52 non-null float64
# LONGITUDE                       52 non-null float64
# ELEVATION                       52 non-null float64
# dtypes: float64(5), object(10)
# memory usage: 11.8+ KB

# %% [markdown]
# The NFL Stadium dataframe contains 15 columns with 100 rows. There are 13 columns that contain NULL values, with only 2 columns that contain full data. Futher investgating will need to be done to determine the correct actions for these NULL values.

# %% [markdown]
# ### NFL Game Details

# %%
nflScore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12667 entries, 0 to 12666
# Data columns (total 17 columns):
# schedule_date          12667 non-null object
# schedule_season        12667 non-null int64
# schedule_week          12667 non-null object
# schedule_playoff       12667 non-null bool
# team_home              12667 non-null object
# score_home             12411 non-null float64
# score_away             12411 non-null float64
# team_away              12667 non-null object
# team_favorite_id       9932 non-null object
# spread_favorite        9932 non-null float64
# over_under_line        9922 non-null object
# stadium                12667 non-null object
# stadium_neutral        12667 non-null bool
# weather_temperature    11934 non-null float64
# weather_wind_mph       11934 non-null float64
# weather_humidity       8388 non-null object
# weather_detail         2637 non-null object
# dtypes: bool(2), float64(5), int64(1), object(9)
# memory usage: 1.5+ MB

# %% [markdown]
# The NFL Game Details dataframe contains 17 columns with 12667 rows. There are 9 columns that contain NULL values. Just like the NFL Stadium Datarame above futher investgating will need to be done.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Stadiums

# %%
nflStadiums.head()
# Out:
#         stadium_name   stadium_location  stadium_open  stadium_close  \
# 0         Alamo Dome    San Antonio, TX           NaN            NaN
# 1     Alltel Stadium   Jacksonville, FL           NaN            NaN
# 2     Alumni Stadium  Chestnut Hill, MA           NaN            NaN
# 3    Anaheim Stadium        Anaheim, CA        1980.0         1994.0
# 4  Arrowhead Stadium    Kansas City, MO        1972.0            NaN
#
#   stadium_type                           stadium_address  \
# 0       indoor     100 Montana St, San Antonio, TX 78203
# 1          NaN                                       NaN
# 2      outdoor     Perimeter Rd, Chestnut Hill, MA 02467
# 3      outdoor  2000 E Gene Autry Way, Anaheim, CA 92806
# 4      outdoor     1 Arrowhead Dr, Kansas City, MO 64129
#
#   stadium_weather_station_code stadium_weather_type stadium_capacity  \
# 0                        78203                 dome            72000
# ...

# %%
nflStadiumsCleaned = nflStadiums.drop(columns=['stadium_open','stadium_close','stadium_address','stadium_weather_station_code','stadium_capacity','STATION','NAME','LATITUDE','LONGITUDE'])

# %%
nflStadiumsCleaned.head()
# Out:
#         stadium_name   stadium_location stadium_type stadium_weather_type  \
# 0         Alamo Dome    San Antonio, TX       indoor                 dome
# 1     Alltel Stadium   Jacksonville, FL          NaN                  NaN
# 2     Alumni Stadium  Chestnut Hill, MA      outdoor                 cold
# 3    Anaheim Stadium        Anaheim, CA      outdoor                 warm
# 4  Arrowhead Stadium    Kansas City, MO      outdoor                 cold
#
#   stadium_surface  ELEVATION
# 0       FieldTurf        NaN
# 1             NaN        NaN
# 2           Grass        NaN
# 3             NaN        NaN
# 4           Grass      264.9

# %%
nflStadiumsCleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
# stadium_name            100 non-null object
# stadium_location        100 non-null object
# stadium_type            93 non-null object
# stadium_weather_type    93 non-null object
# stadium_surface         53 non-null object
# ELEVATION               52 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 4.8+ KB

# %% [markdown]
# Columns that are not neccessary for the analysis were dropped off the DataFrame. This brought the column size to 6 from 15. The values that are NULL in the remaining columns will remain the same. Changing the NULL values to integer 0 will not work because most of the values are of type object and it would not make sense to have it as a integer value. The only numercial column is Elevation, but changing the NULL values to 0 will mean that those entries are at sea-level instead of not having a value.

# %%
nflGames.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/02/1966             1966             1             False
# 1    09/03/1966             1966             1             False
# 2    09/04/1966             1966             1             False
# 3    09/09/1966             1966             2             False
# 4    09/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %% [markdown]
# ### Game Details

# %%
nflGames.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/02/1966             1966             1             False
# 1    09/03/1966             1966             1             False
# 2    09/04/1966             1966             1             False
# 3    09/09/1966             1966             2             False
# 4    09/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %%
nflGamesCleaned = nflGames.drop(columns=['over_under_line','spread_favorite','weather_detail'])

# %%
nflGamesCleaned.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/02/1966             1966             1             False
# 1    09/03/1966             1966             1             False
# 2    09/04/1966             1966             1             False
# 3    09/09/1966             1966             2             False
# 4    09/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id         stadium  stadium_neutral  weather_temperature  \
# 0              NaN     Orange Bowl            False                 83.0
# ...

# %%
nflGamesCleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12667 entries, 0 to 12666
# Data columns (total 14 columns):
# schedule_date          12667 non-null object
# schedule_season        12667 non-null int64
# schedule_week          12667 non-null object
# schedule_playoff       12667 non-null bool
# team_home              12667 non-null object
# score_home             12411 non-null float64
# score_away             12411 non-null float64
# team_away              12667 non-null object
# team_favorite_id       9932 non-null object
# stadium                12667 non-null object
# stadium_neutral        12667 non-null bool
# weather_temperature    11934 non-null float64
# weather_wind_mph       11934 non-null float64
# weather_humidity       8388 non-null object
# dtypes: bool(2), float64(4), int64(1), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# Columns that are not neccessary for the analysis were dropped off the DataFrame. This brought the column size to 14 from 17. The values that are NULL in the remaining columns will remain the same. Changing the NULL values to integer 0 will not work because most of the values are of type object and it would not make sense to have it as a integer value. Changing the NULL values for the numerical values to 0 will skew any of the statistical anaylsis done on those entries since those values will be calculated as 0.

# %%
nflGamesCleaned[pd.isnull(nflGamesCleaned['weather_temperature'])].groupby(by='schedule_season').count()
# Out:
#                  schedule_date  schedule_week  schedule_playoff  team_home  \
# schedule_season
# 1966                        41             41                41         41
# 1967                        58             58                58         58
# 1968                        65             65                65         65
# 1969                        66             66                66         66
# 1979                         8              8                 8          8
# 1980                         8              8                 8          8
# 1981                         8              8                 8          8
# 1982                        14             14                14         14
# 1983                         8              8                 8          8
# 1984                         8              8                 8          8
# 1985                         8              8                 8          8
# ...

# %%
nflGamesCleaned = nflGamesCleaned.dropna(axis=0,subset=['weather_temperature'])

# %%
nflGamesCleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11934 entries, 0 to 12658
# Data columns (total 14 columns):
# schedule_date          11934 non-null object
# schedule_season        11934 non-null int64
# schedule_week          11934 non-null object
# schedule_playoff       11934 non-null bool
# team_home              11934 non-null object
# score_home             11878 non-null float64
# score_away             11878 non-null float64
# team_away              11934 non-null object
# team_favorite_id       9629 non-null object
# stadium                11934 non-null object
# stadium_neutral        11934 non-null bool
# weather_temperature    11934 non-null float64
# weather_wind_mph       11934 non-null float64
# weather_humidity       8388 non-null object
# dtypes: bool(2), float64(4), int64(1), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# A majority of the missing weather data comes from 1966-1969 seasons as well as 200 missing weather entries from 2019. Because weather is a critical factor in this anaylsis, the rows with NULL values will be dropped. This should not effect the outcome since the percentage of NULL entries only around 5.8%.

# %% [markdown]
# ## Outliers

# %%
nflStadiumsCleaned.describe()
# Out:
#          ELEVATION
# count    52.000000
# mean    181.519231
# std     310.972267
# min       1.800000
# 25%      12.250000
# 50%     154.400000
# 75%     212.525000
# max    1611.200000

# %%
nflGamesCleaned.describe()
# Out:
#        schedule_season    score_home    score_away  weather_temperature  \
# count     11934.000000  11878.000000  11878.000000         11934.000000
# mean       1994.479219     22.282287     19.536286            58.618988
# std          14.882158     10.536203     10.125390            15.539685
# min        1966.000000      0.000000      0.000000            -6.000000
# 25%        1982.000000     14.000000     13.000000            48.000000
# 50%        1996.000000     21.000000     19.500000            61.000000
# 75%        2007.000000     29.000000     27.000000            72.000000
# max        2019.000000     72.000000     62.000000            97.000000
#
#        weather_wind_mph
# count      11934.000000
# mean           7.853276
# std            5.627164
# min            0.000000
# 25%            4.000000
# 50%            8.000000
# 75%           12.000000
# max           40.000000

# %% [markdown]
# There were not outliers found within the data. The biggest concern would be if weather temperature had an extreme min or max value but the min and max fit within the norms. The NFL seasons also fall within the range of 1966 - 2019. Also there are not outliersin the game score field, with the values looking normal for a NFL game.
